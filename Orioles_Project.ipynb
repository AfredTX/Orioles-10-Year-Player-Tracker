# %% [markdown]
# <a href="https://colab.research.google.com/github/AfredTX/Orioles-10-Year-Player-Tracker/blob/master/Orioles_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Get it Together!
# !pip install --upgrade --quiet gspread

from google.colab import auth
auth.authenticate_user()

import gspread

from oauth2client.client import GoogleCredentials

from IPython.display import display
gc = gspread.authorize(GoogleCredentials.get_application_default())

import pandas as pd

import matplotlib.pyplot as plt

import requests

from bs4 import BeautifulSoup

from openpyxl import load_workbook
from scipy import stats
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings("ignore")

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
#Create A Workbook!

#wb_create = gc.create('Orioles Lineups 10-19')
sh = gc.open('Orioles Lineups 10-19')
#Create The Sheets!
'''
create_sheet = sh.add_worksheet(title='Batting 2019', rows='100', cols='50')
create_sheet = sh.add_worksheet(title='Pitching 2019', rows='100', cols='50')
create_sheet = sh.add_worksheet(title='Fielding 2019', rows='100', cols='50')
create_sheet = sh.add_worksheet(title='Batting 2018', rows='100', cols='50')
create_sheet = sh.add_worksheet(title='Pitching 2018', rows='100', cols='50')
create_sheet = sh.add_worksheet(title='Fielding 2018', rows='100', cols='50')
create_sheet = sh.add_worksheet(title='Batting 2017', rows='100', cols='50')
create_sheet = sh.add_worksheet(title='Pitching 2017', rows='100', cols='50')
create_sheet = sh.add_worksheet(title='Fielding 2017', rows='100', cols='50')
create_sheet = sh.add_worksheet(title='Batting 2016', rows='100', cols='50')
create_sheet = sh.add_worksheet(title='Pitching 2016', rows='100', cols='50')
create_sheet = sh.add_worksheet(title='Fielding 2016', rows='100', cols='50')
create_sheet = sh.add_worksheet(title='Batting 2015', rows='100', cols='50')
create_sheet = sh.add_worksheet(title='Pitching 2015', rows='100', cols='50')
create_sheet = sh.add_worksheet(title='Fielding 2015', rows='100', cols='50')
create_sheet = sh.add_worksheet(title='Batting 2014', rows='100', cols='50')
create_sheet = sh.add_worksheet(title='Pitching 2014', rows='100', cols='50')
create_sheet = sh.add_worksheet(title='Fielding 2014', rows='100', cols='50')
create_sheet = sh.add_worksheet(title='Batting 2013', rows='100', cols='50')
create_sheet = sh.add_worksheet(title='Pitching 2013', rows='100', cols='50')
create_sheet = sh.add_worksheet(title='Fielding 2013', rows='100', cols='50')
create_sheet = sh.add_worksheet(title='Batting 2012', rows='100', cols='50')
create_sheet = sh.add_worksheet(title='Pitching 2012', rows='100', cols='50')
create_sheet = sh.add_worksheet(title='Fielding 2012', rows='100', cols='50')
create_sheet = sh.add_worksheet(title='Batting 2011', rows='100', cols='50')
create_sheet = sh.add_worksheet(title='Pitching 2011', rows='100', cols='50')
create_sheet = sh.add_worksheet(title='Fielding 2011', rows='100', cols='50')
create_sheet = sh.add_worksheet(title='Batting 2010', rows='100', cols='50')
create_sheet = sh.add_worksheet(title='Pitching 2010', rows='100', cols='50')
create_sheet = sh.add_worksheet(title='Fielding 2010', rows='100', cols='50')'''
# Out:
# "\ncreate_sheet = sh.add_worksheet(title='Batting 2019', rows='100', cols='50')\ncreate_sheet = sh.add_worksheet(title='Pitching 2019', rows='100', cols='50')\ncreate_sheet = sh.add_worksheet(title='Fielding 2019', rows='100', cols='50')\ncreate_sheet = sh.add_worksheet(title='Batting 2018', rows='100', cols='50')\ncreate_sheet = sh.add_worksheet(title='Pitching 2018', rows='100', cols='50')\ncreate_sheet = sh.add_worksheet(title='Fielding 2018', rows='100', cols='50')\ncreate_sheet = sh.add_worksheet(title='Batting 2017', rows='100', cols='50')\ncreate_sheet = sh.add_worksheet(title='Pitching 2017', rows='100', cols='50')\ncreate_sheet = sh.add_worksheet(title='Fielding 2017', rows='100', cols='50')\ncreate_sheet = sh.add_worksheet(title='Batting 2016', rows='100', cols='50')\ncreate_sheet = sh.add_worksheet(title='Pitching 2016', rows='100', cols='50')\ncreate_sheet = sh.add_worksheet(title='Fielding 2016', rows='100', cols='50')\ncreate_sheet = sh.add_worksheet(title='Batting 2015
# ...

# %%
def stat_stripper_bat_pit(cat):
  if cat == 'Batting 2019':
    url = 'https://www.espn.com/mlb/team/stats/_/name/bal/season/2019/seasontype/2'
    sheet = sh.worksheet('Batting 2019')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:S100')
    cell_adv_stats = sheet.range('T2:AI100')
    cell_players =sheet.range('A2:A99')
    cell_positions = sheet.range('B1:B99') 
    players_num = 32
    reg_stat_end = 544+34-2
    adv_cell_start = 608
    adv_cell_end = -16+16
  elif cat == 'Pitching 2019':
    url = 'https://www.espn.com/mlb/team/stats/_/type/pitching/name/bal/season/2019/seasontype/2'
    sheet = sh.worksheet('Pitching 2019')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:T100')
    cell_adv_stats = sheet.range('U2:AF100')
    cell_players =sheet.range('A2:A99')
    cell_positions = sheet.range('B1:B99') 
    players_num = 39
    reg_stat_end = 723+18
    adv_cell_start = 780
    adv_cell_end = 1236+88
  
  elif cat == 'Batting 2018':
    url = 'https://www.espn.com/mlb/team/stats/_/name/bal/season/2018/seasontype/2'
    sheet = sh.worksheet('Batting 2018')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:S100')
    cell_adv_stats = sheet.range('T2:AI100')
    cell_players =sheet.range('A2:A99')
    cell_positions = sheet.range('B1:B99') 
    players_num = 36
    reg_stat_end = 544+85-8+19
    adv_cell_start = 608+76
    adv_cell_end = -16-16
  elif cat == 'Pitching 2018':
    url = 'https://www.espn.com/mlb/team/stats/_/type/pitching/name/bal/season/2018/seasontype/2'
    sheet = sh.worksheet('Pitching 2018')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:T100')
    cell_adv_stats = sheet.range('U2:AF100')
    cell_players = sheet.range('A2:A99')
    cell_positions = sheet.range('B1:B99') 
    players_num = 31
    reg_stat_end = 723-126-18
    adv_cell_start = 780-160
    adv_cell_end = 1236
  
  elif cat == 'Batting 2017':
    url = 'https://www.espn.com/mlb/team/stats/_/name/bal/season/2017/seasontype/2'
    sheet = sh.worksheet('Batting 2017')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:S100')
    cell_adv_stats = sheet.range('T2:AI100')
    cell_players =sheet.range('A2:A99')
    cell_positions = sheet.range('B1:B99') 
    players_num = 32+19
    reg_stat_end = 544+374
    adv_cell_start = 608+366-5
    adv_cell_end = -16-16
  elif cat == 'Pitching 2017':
    url = 'https://www.espn.com/mlb/team/stats/_/type/pitching/name/bal/season/2017/seasontype/2'
    sheet = sh.worksheet('Pitching 2017')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:T100')
    cell_adv_stats = sheet.range('U2:AF100')
    cell_players =sheet.range('A2:A99')
    cell_positions = sheet.range('B1:B99') 
    players_num = 27
    reg_stat_end = 723-199-11
    adv_cell_start = 780-240
    adv_cell_end = 1236
  
  elif cat == 'Batting 2016':
    url = 'https://www.espn.com/mlb/team/stats/_/name/bal/season/2016/seasontype/2'
    sheet = sh.worksheet('Batting 2016')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:S100')
    cell_adv_stats = sheet.range('T2:AI100')
    cell_players =sheet.range('A2:A99')
    cell_positions = sheet.range('B1:B99') 
    players_num = 32+16
    reg_stat_end = 544+320
    adv_cell_start = 608+228+76
    adv_cell_end = -16-16
  elif cat == 'Pitching 2016':
    url = 'https://www.espn.com/mlb/team/stats/_/type/pitching/name/bal/season/2016/seasontype/2'
    sheet = sh.worksheet('Pitching 2016')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:T100')
    cell_adv_stats = sheet.range('U2:AF100')
    cell_players =sheet.range('A2:A99')
    cell_positions = sheet.range('B1:B99') 
    players_num = 28
    reg_stat_end = 723-181-10
    adv_cell_start = 780-230+10
    adv_cell_end = 1236
  
  elif cat == 'Batting 2015':
    url = 'https://www.espn.com/mlb/team/stats/_/name/bal/season/2015/seasontype/2'
    sheet = sh.worksheet('Batting 2015')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:S100')
    cell_adv_stats = sheet.range('T2:AI100')
    cell_players =sheet.range('A2:A99')
    cell_positions = sheet.range('B1:B99') 
    players_num = 32+17
    reg_stat_end = 544+340-2
    adv_cell_start = 608+323
    adv_cell_end = -16-304-19
  elif cat == 'Pitching 2015':
    url = 'https://www.espn.com/mlb/team/stats/_/type/pitching/name/bal/season/2015/seasontype/2'
    sheet = sh.worksheet('Pitching 2015')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:T100')
    cell_adv_stats = sheet.range('U2:AF100')
    cell_players =sheet.range('A2:A99')
    cell_positions = sheet.range('B1:B99') 
    players_num = 23
    reg_stat_end = 723-270-16-16
    adv_cell_start = 780-276-44
    adv_cell_end = 1236
  
  elif cat == 'Batting 2014':
    url = 'https://www.espn.com/mlb/team/stats/_/name/bal/season/2014/seasontype/2'
    sheet = sh.worksheet('Batting 2014')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:S100')
    cell_adv_stats = sheet.range('T2:AI100')
    cell_players =sheet.range('A2:A99')
    cell_positions = sheet.range('B1:B99') 
    players_num = 32+13
    reg_stat_end = 544+264
    adv_cell_start = 608+247
    adv_cell_end = -16-247-16
  elif cat == 'Pitching 2014':
    url = 'https://www.espn.com/mlb/team/stats/_/type/pitching/name/bal/season/2014/seasontype/2'
    sheet = sh.worksheet('Pitching 2014')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:T100')
    cell_adv_stats = sheet.range('U2:AF100')
    cell_players =sheet.range('A2:A99')
    cell_positions = sheet.range('B1:B99') 
    players_num = 21
    reg_stat_end = 723-256-68
    adv_cell_start = 780-152-208
    adv_cell_end = 1236
  
  elif cat == 'Batting 2013':
    url = 'https://www.espn.com/mlb/team/stats/_/name/bal/season/2013/seasontype/2'
    sheet = sh.worksheet('Batting 2013')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:S100')
    cell_adv_stats = sheet.range('T2:AI100')
    cell_players =sheet.range('A2:A99')
    cell_positions = sheet.range('B1:B99') 
    players_num = 32+21
    reg_stat_end = 544+410
    adv_cell_start = 608+399
    adv_cell_end = -16-349-16
  elif cat == 'Pitching 2013':
    url = 'https://www.espn.com/mlb/team/stats/_/type/pitching/name/bal/season/2013/seasontype/2'
    sheet = sh.worksheet('Pitching 2013')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:T100')
    cell_adv_stats = sheet.range('U2:AF100')
    cell_players =sheet.range('A2:A99')
    cell_positions = sheet.range('B1:B99') 
    players_num = 27
    reg_stat_end = 723-210
    adv_cell_start = 780-240
    adv_cell_end = 1236
  
  elif cat == 'Batting 2012':
    url = 'https://www.espn.com/mlb/team/stats/_/name/bal/season/2012/seasontype/2'
    sheet = sh.worksheet('Batting 2012')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:S100')
    cell_adv_stats = sheet.range('T2:AI100')
    cell_players =sheet.range('A2:A99')
    cell_positions = sheet.range('B1:B99') 
    players_num = 32+21
    reg_stat_end = 544+410
    adv_cell_start = 608+399
    adv_cell_end = -16-349
  elif cat == 'Pitching 2012':
    url = 'https://www.espn.com/mlb/team/stats/_/type/pitching/name/bal/season/2012/seasontype/2'
    sheet = sh.worksheet('Pitching 2012')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:T100')
    cell_adv_stats = sheet.range('U2:AF100')
    cell_players =sheet.range('A2:A99')
    cell_positions = sheet.range('B1:B99') 
    players_num = 27
    reg_stat_end = 723-210
    adv_cell_start = 780-240
    adv_cell_end = 1236
  
  elif cat == 'Batting 2011':
    url = 'https://www.espn.com/mlb/team/stats/_/name/bal/season/2011/seasontype/2'
    sheet = sh.worksheet('Batting 2011')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:S100')
    cell_adv_stats = sheet.range('T2:AI100')
    cell_players =sheet.range('A2:A99')
    cell_positions = sheet.range('B1:B99') 
    players_num = 32+19
    reg_stat_end = 544+352+5+16
    adv_cell_start = 608+361
    adv_cell_end = -16-361
  elif cat == 'Pitching 2011':
    url = 'https://www.espn.com/mlb/team/stats/_/type/pitching/name/bal/season/2011/seasontype/2'
    sheet = sh.worksheet('Pitching 2011')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:T100')
    cell_adv_stats = sheet.range('U2:AF100')
    cell_players =sheet.range('A2:A99')
    cell_positions = sheet.range('B1:B99') 
    players_num = 28
    reg_stat_end = 723-191
    adv_cell_start = 780-220
    adv_cell_end = 1236
  
  elif cat == 'Batting 2010':
    url = 'https://www.espn.com/mlb/team/stats/_/name/bal/season/2010/seasontype/2'
    sheet = sh.worksheet('Batting 2010')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:S100')
    cell_adv_stats = sheet.range('T2:AI100')
    cell_players =sheet.range('A2:A99')
    cell_positions = sheet.range('B1:B99') 
    players_num = 32+14
    reg_stat_end = 544+289-5
    adv_cell_start = 608+256+10
    adv_cell_end = -16
  elif cat == 'Pitching 2010':
    url = 'https://www.espn.com/mlb/team/stats/_/type/pitching/name/bal/season/2010/seasontype/2'
    sheet = sh.worksheet('Pitching 2010')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:T100')
    cell_adv_stats = sheet.range('U2:AF100')
    cell_players =sheet.range('A2:A99')
    cell_positions = sheet.range('B1:B99') 
    players_num = 24
    reg_stat_end = 723-274
    adv_cell_start = 780-188-104-8
    adv_cell_end = 1236
  
  else:
    return 'Cat not recognized'


  response = requests.get(url)
  if(response.ok):
    data = response.text
  soup = BeautifulSoup(data, 'html.parser')

  # get the headers
  raw_headers = soup.find_all(class_= 'fw-medium w-100 dib underline tar stats-cell')
  stat_headers = [i.get_text() for i in raw_headers]
  #write headers to worksheet

  for i, val in enumerate(stat_headers):
    cell_headers[i].value = val
  sheet.update_cells(cell_headers)

  #get the numbers
  raw_stats = soup.find_all(class_= 'Table__TD')
  cooked_stats = [i.get_text() for i in raw_stats]
  players = cooked_stats[:players_num]
  players_list = [i.replace('1B', '').replace('2B', '').replace('3B', '').replace('CF', '').replace('RP', '').replace('SP', '')\
                  .replace('SS', '').replace('RF', '').replace('LF', '').replace('DH', ''.replace('*', '')) for i in players]
  final_plist = [e.rstrip('C') for e in players_list]
  
      
  no_as = [i.replace('*', '').replace('C', ' C') for i in players]
  pos = [i[-3:] for i in no_as]
  position = [i.strip() for i in pos]
  position_column = ['Pos'] + position
  final_pos_col = position_column[:(players_num)]

  reg_stat_lines = cooked_stats[players_num:reg_stat_end]
  adv_stat_lines = cooked_stats[adv_cell_start:adv_cell_end]

  for i, val in enumerate(final_plist):
    cell_players[i].value = val
  sheet.update_cells(cell_players)

  for i, val in enumerate(final_pos_col):
    cell_positions[i].value = val
  sheet.update_cells(cell_positions)

  for i, val in enumerate(reg_stat_lines):
    cell_stats[i].value = val
  sheet.update_cells(cell_stats)

  for i, val in enumerate(adv_stat_lines):
    cell_adv_stats[i].value = val
  sheet.update_cells(cell_adv_stats)

# %%
def stat_stripper_field(cat):
  if cat == 'Fielding 2019':
    url = 'https://www.espn.com/mlb/team/stats/_/type/fielding/name/bal/season/2019/seasontype/2'
    sheet = sh.worksheet('Fielding 2019')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:M100')
    cell_players =sheet.range('A2:A99')
    cell_positions = sheet.range('B1:B99') 
    players_num = 43
    reg_stat_end = 723
    adv_cell_start = 780
    adv_cell_end = 1236
  
  elif cat == 'Fielding 2018':
    url = 'https://www.espn.com/mlb/team/stats/_/type/fielding/name/bal/season/2018/seasontype/2'
    sheet = sh.worksheet('Fielding 2018')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:M100')
    cell_players =sheet.range('A2:A100')
    cell_positions = sheet.range('B1:B99') 
    players_num = 43+6
    reg_stat_end = 723
    adv_cell_start = 780
    adv_cell_end = 1236
  
  elif cat == 'Fielding 2017':
    url = 'https://www.espn.com/mlb/team/stats/_/type/fielding/name/bal/season/2017/seasontype/2'
    sheet = sh.worksheet('Fielding 2017')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:M100')
    cell_players =sheet.range('A2:A100')
    cell_positions = sheet.range('B1:B99') 
    players_num = 43+8
    reg_stat_end = 723
    adv_cell_start = 780
    adv_cell_end = 1236
  
  elif cat == 'Fielding 2016':
    url = 'https://www.espn.com/mlb/team/stats/_/type/fielding/name/bal/season/2016/seasontype/2'
    sheet = sh.worksheet('Fielding 2016')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:M100')
    cell_players =sheet.range('A2:A100')
    cell_positions = sheet.range('B1:B99') 
    players_num = 43+4
    reg_stat_end = 723
    adv_cell_start = 780
    adv_cell_end = 1236
  
  elif cat == 'Fielding 2015':
    url = 'https://www.espn.com/mlb/team/stats/_/type/fielding/name/bal/season/2015/seasontype/2'
    sheet = sh.worksheet('Fielding 2015')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:M100')
    cell_players =sheet.range('A2:A100')
    cell_positions = sheet.range('B1:B99') 
    players_num = 43+6
    reg_stat_end = 723
    adv_cell_start = 780
    adv_cell_end = 1236
  
  elif cat == 'Fielding 2014':
    url = 'https://www.espn.com/mlb/team/stats/_/type/fielding/name/bal/season/2014/seasontype/2'
    sheet = sh.worksheet('Fielding 2014')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:M100')
    cell_players =sheet.range('A2:A100')
    cell_positions = sheet.range('B1:B99') 
    players_num = 43+1
    reg_stat_end = 723
    adv_cell_start = 780
    adv_cell_end = 1236
  
  elif cat == 'Fielding 2013':
    url = 'https://www.espn.com/mlb/team/stats/_/type/fielding/name/bal/season/2013/seasontype/2'
    sheet = sh.worksheet('Fielding 2013')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:M100')
    cell_players =sheet.range('A2:A100')
    cell_positions = sheet.range('B1:B99') 
    players_num = 43+10
    reg_stat_end = 723
    adv_cell_start = 780
    adv_cell_end = 1236
  
  elif cat == 'Fielding 2012':
    url = 'https://www.espn.com/mlb/team/stats/_/type/fielding/name/bal/season/2012/seasontype/2'
    sheet = sh.worksheet('Fielding 2012')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:M100')
    cell_players =sheet.range('A2:A99')
    cell_positions = sheet.range('B1:B99') 
    players_num = 43+9
    reg_stat_end = 723
    adv_cell_start = 780
    adv_cell_end = 1236
  
  elif cat == 'Fielding 2011':
    url = 'https://www.espn.com/mlb/team/stats/_/type/fielding/name/bal/season/2011/seasontype/2'
    sheet = sh.worksheet('Fielding 2011')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:M100')
    cell_players =sheet.range('A2:A99')
    cell_positions = sheet.range('B1:B99') 
    players_num = 43+7
    reg_stat_end = 723
    adv_cell_start = 780
    adv_cell_end = 1236
  
  elif cat == 'Fielding 2010':
    url = 'https://www.espn.com/mlb/team/stats/_/type/fielding/name/bal/season/2010/seasontype/2'
    sheet = sh.worksheet('Fielding 2010')
    cell_headers = sheet.range('C1:AI1')
    cell_stats = sheet.range('C2:M100')
    cell_players =sheet.range('A2:A99')
    cell_positions = sheet.range('B1:B99') 
    players_num = 43+3
    reg_stat_end = 723
    adv_cell_start = 780
    adv_cell_end = 1236
  else:
    return 'Cat not recognized'


  response = requests.get(url)
  if(response.ok):
    data = response.text
  soup = BeautifulSoup(data, 'html.parser')

  # get the headers
  raw_headers = soup.find_all(class_= 'fw-medium w-100 dib underline tar stats-cell')
  stat_headers = [i.get_text() for i in raw_headers]
  #write headers to worksheet

  for i, val in enumerate(stat_headers):
    cell_headers[i].value = val
  sheet.update_cells(cell_headers)

  #get the numbers
  raw_stats = soup.find_all(class_= 'Table__TD')
  cooked_stats = [i.get_text() for i in raw_stats]
  players = cooked_stats[:players_num]
  players_list = [i.replace('1B', '').replace('2B', '').replace('3B', '').replace('CF', '').replace('RP', '').replace('SP', '')\
                  .replace('SS', '').replace('RF', '').replace('LF', '').replace('DH', ''.replace('*', '')) for i in players]
  final_plist = [e.rstrip('C') for e in players_list]
  
      
  no_as = [i.replace('*', '').replace('C', ' C') for i in players]
  pos = [i[-3:] for i in no_as]
  position = [i.strip() for i in pos]
  position_column = ['Pos'] + position
  final_pos_col = position_column[:(players_num)]

  reg_stat_lines = cooked_stats[players_num:reg_stat_end]
  adv_stat_lines = cooked_stats[adv_cell_start:adv_cell_end]

  for i, val in enumerate(final_plist):
    cell_players[i].value = val
  sheet.update_cells(cell_players)

  for i, val in enumerate(final_pos_col):
    cell_positions[i].value = val
  sheet.update_cells(cell_positions)

  for i, val in enumerate(reg_stat_lines):
    cell_stats[i].value = val
  sheet.update_cells(cell_stats)

# %%
stat_stripper_bat_pit('Batting 2019')
stat_stripper_bat_pit('Pitching 2019')
stat_stripper_field('Fielding 2019')
stat_stripper_bat_pit('Batting 2018')
stat_stripper_bat_pit('Pitching 2018')
stat_stripper_field('Fielding 2018')
stat_stripper_bat_pit('Batting 2017')
stat_stripper_bat_pit('Pitching 2017')
stat_stripper_field('Fielding 2017')
stat_stripper_bat_pit('Batting 2016')
stat_stripper_bat_pit('Pitching 2016')
stat_stripper_field('Fielding 2016')
stat_stripper_bat_pit('Batting 2015')
stat_stripper_bat_pit('Pitching 2015')
stat_stripper_field('Fielding 2015')
stat_stripper_bat_pit('Batting 2014')
stat_stripper_bat_pit('Pitching 2014')
stat_stripper_field('Fielding 2014')
stat_stripper_bat_pit('Batting 2013')
stat_stripper_bat_pit('Pitching 2013')
stat_stripper_field('Fielding 2013')
stat_stripper_bat_pit('Batting 2012')
stat_stripper_bat_pit('Pitching 2012')
stat_stripper_field('Fielding 2012')
stat_stripper_bat_pit('Batting 2011')
stat_stripper_bat_pit('Pitching 2011')
stat_stripper_field('Fielding 2011')
stat_stripper_bat_pit('Batting 2010')
stat_stripper_bat_pit('Pitching 2010')
stat_stripper_field('Fielding 2010')
